# %%
from mcp_browser_api.client import MCPBrowserClient

client = MCPBrowserClient()
results = client.search("what is india", search_engine="brave")
results
# Out:
# {'results': [{'title': 'AI Generated Answer',
#    'url': 'brave://ai-generated-answer',
#    'snippet': 'No answer provided.',
#    'content': '',
#    'source_type': 'llm_answer',
#    'metadata': {'search_engine': 'brave', 'query': 'what is india'}},
#   {'title': 'India - Wikipedia',
#    'url': 'https://en.wikipedia.org/wiki/India',
#    'snippet': "2 hours ago - India, officially the Republic of India, is a country in South Asia. It is the seventh-largest country by area; the most populous country from June 2023 onwards; and since its independence in 1947, the world's most populous democracy. Bounded by the Indian Ocean on the south, the Arabian Sea ...",
#    'content': '',
#    'source_type': 'web_search_result',
#    'metadata': {'search_engine': 'brave',
#     'position': 1,
#     'query': 'what is india',
#     'raw_element_index': 1}},
#   {'title': 'India | History, Map, Population, Economy, & Facts | Britannica',
#    'url': 'https://www.britannica.com/place/India',
# ...

# %%
results
# Out:
# {'results': [],
#  'query': 'trump ',
#  'search_engine': 'brave',
#  'timestamp': '2025-04-20T12:47:01.666004'}
